# %%
import hopsworks
import joblib
import pandas as pd
import numpy as np

project = hopsworks.login()
fs = project.get_feature_store()
mr = project.get_model_registry()
# Out:
# 2026-02-05 16:38:12,773 INFO: Initializing external client
# 2026-02-05 16:38:12,788 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2026-02-05 16:38:16,103 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1338518

# %%
# FETCH LATEST FEATURES 

FEATURE_VIEW_NAME = "aqi_feature_view"
FEATURE_VIEW_VERSION = 1

fv = fs.get_feature_view(
    name=FEATURE_VIEW_NAME,
    version=FEATURE_VIEW_VERSION
)

# Fetch latest data (for next prediction window)
inference_df = fv.get_batch_data()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 12
#       6 fv = fs.get_feature_view(
#       7     name=FEATURE_VIEW_NAME,
#       8     version=FEATURE_VIEW_VERSION
#       9 )
#      11 # Fetch latest data (for next prediction window)
# ---> 12 inference_df = fv.get_batch_data()
#
# AttributeError: 'NoneType' object has no attribute 'get_batch_data'

# %%
fs.get_feature_views()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 fs.get_feature_views()
#
# File ~\OneDrive\Desktop\AQI Predictor\venv\lib\site-packages\hopsworks_common\usage.py:246, in method_logger.<locals>.wrapper(*args, **kwargs)
#     244 except Exception as e:
#     245     exception = e
# --> 246     raise e
#     247 finally:
#     248     try:
#
# File ~\OneDrive\Desktop\AQI Predictor\venv\lib\site-packages\hopsworks_common\usage.py:242, in method_logger.<locals>.wrapper(*args, **kwargs)
#     239 exception = None
#     240 try:
#     241     # Call the original method
# --> 242     result = func(*args, **kwargs)
#     243     return result
#     244 except Exception as e:
#
# TypeError: FeatureStore.get_feature_views() missing 1 required positional argument: 'name'
